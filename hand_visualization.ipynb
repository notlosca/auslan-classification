# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bottom_line = [0,5]
finger_line = [0,1]
thumb_ver = [0,3]
forefinger_ver = [0,4]
middlefinger_ver = [0,4.5]
ringfinger_ver = [0,4.25]
littlefinger_ver = [0,3.7]

bottom_line = [[0,0], [0,5]]
'''fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection='3d')'''
# Out:
# "fig = plt.figure(figsize=(12,10))\nax = fig.add_subplot(projection='3d')"

# %%
from matplotlib.path import Path
import matplotlib.patches as patches


# (x,y)
verts = [
    (0.,0.),
    (5.,0.),
    (5.,5.), # little finger
    (4.,5.), # little finger
    (4.,3.), # separate fingers
    (4.,6.5), # ring finger
    (3.,6.5), # ring finger
    (3.,3.), # separate fingers
    (3.,7.), # middle finger
    (2.,7.), # middle finger
    (2.,3.), # separate fingers
    (2.,6.25), # forefinger
    (1.,6.25), #forefinger
    (1.,2.), # separate fingers
    (1.,3.), # thumb
    (0.,3.), # thumb
    (0.,0.)
]

scale_verts = [(i[0]*0.75, i[1]) for i in verts]

##--- Centre the figure ---##
x_max = np.max([i[0] for i in scale_verts])
x_min = np.min([i[0] for i in scale_verts])

y_max = np.max([i[1] for i in scale_verts])
y_min = np.min([i[1] for i in scale_verts])

new_scale_verts = [(i[0]-x_max/2, i[1]-y_max/2) for i in scale_verts]
##--- Centre the figure ---##

codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]

path = Path(new_scale_verts, codes)

fig, ax = plt.subplots(figsize=(12,10))
patch = patches.PathPatch(path, facecolor='orange', lw=2)
#ax.add_patch(patch)

###### background patch ######
threshold = 0.3

verts1 = [
    (-x_max/2 - threshold, -y_max/2 - threshold),
    (x_max/2 + threshold, -y_max/2 - threshold),
    (x_max/2 + threshold, y_max/2 + threshold),
    (-x_max/2 - threshold, y_max/2 + threshold),
    (-x_max/2 - threshold, -y_max/2 - threshold)
]

codes1 = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]
path1 = Path(verts1, codes1)
patch1 = patches.PathPatch(path1, facecolor='orange', lw=2)
###### background patch ######

# add patches
ax.add_patch(patch1)
ax.add_patch(patch)

ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
plt.axis("off")
plt.title("Za Hando")
plt.show()

# %%
roll = np.linspace(-.5,.5, endpoint=True, num=5)*180
roll
# Out:
# array([-90., -45.,   0.,  45.,  90.])

# %%
verts_list = []
for i in roll:
    verts_i = [(np.cos(i)*j[0], np.sin(i)*j[1]) for j in verts]
    verts_list.append(verts_i)
verts_list[1]
# Out:
# [(0.0, -0.0),
#  (2.626609944088649, -0.0),
#  (2.626609944088649, -4.254517622670592),
#  (2.101287955270919, -4.254517622670592),
#  (2.101287955270919, -2.552710573602355),
#  (2.101287955270919, -5.5308729094717695),
#  (1.575965966453189, -5.5308729094717695),
#  (1.575965966453189, -2.552710573602355),
#  (1.575965966453189, -5.956324671738829),
#  (1.0506439776354595, -5.956324671738829),
#  (1.0506439776354595, -2.552710573602355),
#  (1.0506439776354595, -5.31814702833824),
#  (0.5253219888177297, -5.31814702833824),
#  (0.5253219888177297, -1.7018070490682369),
#  (0.5253219888177297, -2.552710573602355),
#  (0.0, -2.552710573602355),
#  (0.0, -0.0)]

# %%
# (x,y)
verts = [
    (0.,0.),
    (5.,0.),
    (5.,5.), # little finger
    (4.,5.), # little finger
    (4.,3.), # separate fingers
    (4.,6.5), # ring finger
    (3.,6.5), # ring finger
    (3.,3.), # separate fingers
    (3.,7.), # middle finger
    (2.,7.), # middle finger
    (2.,3.), # separate fingers
    (2.,6.25), # forefinger
    (1.,6.25), #forefinger
    (1.,2.), # separate fingers
    (1.,3.), # thumb
    (0.,3.), # thumb
    (0.,0.)
]
for vl in verts_list:
    scale_verts = [(i[0]*0.75, i[1]) for i in vl]

    ##--- Centre the figure ---##
    x_max = np.max([i[0] for i in scale_verts])
    x_min = np.min([i[0] for i in scale_verts])

    y_max = np.max([i[1] for i in scale_verts])
    y_min = np.min([i[1] for i in scale_verts])

    new_scale_verts = [(i[0]-x_max/2, i[1]-y_max/2) for i in scale_verts]
    ##--- Centre the figure ---##

    codes = [
        Path.MOVETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.CLOSEPOLY,
    ]

    path = Path(new_scale_verts, codes)

    fig, ax = plt.subplots(figsize=(12,10))
    patch = patches.PathPatch(path, facecolor='orange', lw=2)

    ax.add_patch(patch)

    ax.set_xlim(-5,5)
    ax.set_ylim(-5,5)
    #plt.axis("off")
    #plt.title("Za Hando")
    plt.show()

# %%
def rotation_matrix(theta:float) -> np.ndarray:
    return np.array([
        [np.cos(theta), - np.sin(theta)],
        [np.sin(theta), np.cos(theta)]
    ])

# %%
ary = np.array(verts[:2])
plt.scatter(ary[:,0], ary[:,1])

# %%
angle = roll[2]
rotation_matrix(angle)
# Out:
# array([[ 1., -0.],
#        [ 0.,  1.]])

# %%
for theta in roll:
    mat = rotation_matrix(theta)
    p = np.dot(mat, ary)
    plt.scatter(p[:,0], p[:,1])

plt.scatter(ary[:,0], ary[:,1])

# %%
rotation_matrix(30)@ary
# Out:
# array([[4.94015812, 0.        ],
#        [0.77125725, 0.        ]])

# %%
ary
# Out:
# array([[0., 0.],
#        [5., 0.]])
