# %% [markdown]
# # Linear PCA

# %%
import pandas as pd
import numpy as np
import os
from utils import base

# %% [markdown]
# ## Read and create the dataset

# %%
path = "./tctodd/"
#path = "../../Desktop/MML Project/tctodd/"
dirs = os.listdir(path=path)
weeks = sorted([i for i in dirs if i != ".DS_Store"])
filenames = sorted(os.listdir(path+weeks[1]))

data = []
labels = dict()
label_cnt = 0

for w in weeks:
    temp_path = path+w+"/"
    filenames = sorted(os.listdir(temp_path))
    for fn in filenames:
        label = fn.split('.')[0][:-2]
        
        if label not in labels:
            labels[label] = label_cnt
            label_cnt += 1
            
        data.append({'label':labels[label], 'time_series':pd.read_csv(temp_path+fn, header=None, sep='\t',).values})

# %%
df = pd.DataFrame(data, columns=['label', 'time_series'])
print(df['label'].value_counts())
df.head()
# Out:
# 0     27
# 60    27
# 69    27
# 68    27
# 67    27
#       ..
# 29    27
# 28    27
# 27    27
# 26    27
# 94    27
# Name: label, Length: 95, dtype: int64
#    label                                        time_series
# 0      0  [[-0.064909, 0.034318, -0.043964, 0.626383, 0....
# 1      0  [[-0.107059, -0.126109, -0.053742, 0.612516, 0...
# 2      0  [[-0.061427, -0.082576, -0.102991, 0.735469, 0...
# 3      1  [[-0.128178, 0.02695, -0.050126, 0.455028, 0.4...
# 4      1  [[-0.143672, -0.144416, -0.047447, 0.660979, 0...

# %%
from sklearn.model_selection import train_test_split
X = df['time_series']
y = df['label']
seed = 0
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y, 
                                                    test_size=0.222222222222222, random_state=seed)
X_train, X_test = X_train.reset_index(drop=True),X_test.reset_index(drop=True)
y_train, y_test = y_train.reset_index(drop=True), y_test.reset_index(drop=True)

# %%
y_train.value_counts()
# Out:
# 19    21
# 23    21
# 8     21
# 61    21
# 44    21
#       ..
# 53    21
# 9     21
# 64    21
# 93    21
# 94    21
# Name: label, Length: 95, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA

n_coords = 60
X_interp = base.interpolate_data(X_train, n_coords)
X_interp = base.concatenate_examples(X_interp)


SC = StandardScaler()
SC.fit(X_interp)
X_interp = SC.transform(X_interp)
kpca = KernelPCA(n_components=None, kernel='linear')

principal_comps = kpca.fit_transform(X_interp)

# find the proportion of variance explained
explained_variance = np.var(principal_comps, axis=0)
explained_variance_ratio = explained_variance / np.sum(explained_variance)

# %%
import matplotlib.pyplot as plt
cum_sum_eigenvalues = np.cumsum(explained_variance_ratio)
plt.figure(figsize=(12,7))

plt.bar(range(0,len(explained_variance_ratio[:70])), explained_variance_ratio[:70], alpha=0.6, align='center', label='Individual explained variance', color='k')
plt.step(range(0,len(cum_sum_eigenvalues[:70])), cum_sum_eigenvalues[:70], where='mid',label='Cumulative explained variance', color='tab:orange')
plt.scatter(54,.95, color='tab:red', s=100, edgecolors='k', facecolors='none')
plt.hlines(y=.95, xmin=-1, xmax=54, linestyles='--', colors='k')
plt.vlines(x=54, ymin=0,ymax=0.95, linestyles='--', colors='k')
x_ticks = list(np.linspace(0,1,endpoint=True, num=11))
x_ticks.append(.95)

plt.ylabel('Explained variance ratio', fontsize=15)
plt.xlabel('Principal component index', fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(sorted(x_ticks), fontsize=13)
plt.xlim(-1,70)
plt.legend(loc=10, fontsize=15)
plt.tight_layout()
plt.savefig("../images/screeplot.png", format='png', dpi=300)
plt.show()

# %%
print(f'first 54 dims {cum_sum_eigenvalues[53]} var explained')
# Out:
# first 54 dims 0.9511070637497042 var explained

# %%
import sklearn as sk
n_folds = 5
skf = sk.model_selection.StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)

# %% [markdown]
# ## SVC

# %%
import itertools
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from tqdm import tqdm
from utils import base
seed = 0

n_pcs = 54
n_coords = 60

##LINEAR KERNEL
params = [['linear'], [0.0001, 0.0005, 0.001, 0.005, 0.01, 1]]
params_comb = list(itertools.product(*params))
##RBF KERNEL
params = [['rbf'], [0.0001, 0.0005, 0.001, 0.005, 0.01, 1], [0.001, 0.01, 1, 2, 5, 10]]
params_comb += list(itertools.product(*params))
##POLYNOMIAL KERNEL
params = [['poly'], [0.0001, 0.0005, 0.001, 0.005, 0.01, 1], [0.001, 0.01, 1, 2, 5, 10], [3, 6, 10, 15, 20, 25, 30], [0, 0.1, 0.5, 1, 5, 10]]
params_comb += list(itertools.product(*params))

# 5-fold cross-validation
acc_scores = np.zeros(len(params_comb))
for train_index, val_index in skf.split(X_train, y_train):
    X_train_cv = X_train.iloc[train_index]
    y_train_cv = y_train.iloc[train_index]
    X_val_cv = X_train.iloc[val_index]
    y_val_cv = y_train.iloc[val_index]

    X_train_interp, X_test_interp = base.interpolate_data(X_train_cv, n_coords), base.interpolate_data(X_val_cv, n_coords)
    X_train_interp = base.concatenate_examples(X_train_interp)
    X_test_interp = base.concatenate_examples(X_test_interp)


    SC = StandardScaler()
    SC.fit(X_train_interp)
    X_train_interp = SC.transform(X_train_interp)
    X_test_interp = SC.transform(X_test_interp)

    kpca = KernelPCA(n_components=None, kernel='linear')

    principal_comps_train = kpca.fit_transform(X_train_interp)
    principal_comps_test = kpca.transform(X_test_interp)
    princ_components = principal_comps_train[:, :n_pcs]
    test_princ_components = principal_comps_test[:, :n_pcs]
    for i, params in enumerate(tqdm(params_comb, desc='doing parameters search...')):
        if len(params) == 2:
            combination = tuple([params[0], params[1], 1, 3, 0])
        elif len(params) == 3:
            combination = tuple([params[0], params[1], params[2], 3, 0])
        else:
            combination = params
        svc = SVC(kernel=combination[0], C=combination[1], gamma=combination[2], degree=combination[3], coef0=combination[4], max_iter=1000)
        svc.fit(princ_components, y_train_cv.values)
        predictions = svc.predict(test_princ_components)
        res = accuracy_score(y_val_cv.values, predictions)
        acc_scores[i] += res
acc_scores = acc_scores / n_folds
best_idx = np.argmax(acc_scores)    
print(f'Found best combination! {params_comb[best_idx]} w. accuracy of {acc_scores[best_idx]}.')
best_comb = params_comb[best_idx]
# Out:
# doing parameters search...:   7%|▋         | 114/1554 [01:07<16:12,  1.48it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   7%|▋         | 115/1554 [01:08<16:01,  1.50it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   7%|▋         | 116/1554 [01:09<16:11,  1.48it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 117/1554 [01:09<16:05,  1.49it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 118/1554 [01:10<15:56,  1.50it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 119/1554 [01:10<15:43,  1.52it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 120/1554 [01:11<15:28,  1.54it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 121/1554 [01:12<15:50,  1.51it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 122/1554 [01:12<16:08,  1.48it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 123/1554 [01:13<16:21,  1.46it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 124/1554 [01:14<16:27,  1.45it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   8%|▊         | 125/1554 [01:14<15:41,  1.52it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   9%|▉         | 144/1554 [01:25<14:15,  1.65it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   9%|▉         | 145/1554 [01:25<10:58,  2.14it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   9%|▉         | 146/1554 [01:25<08:40,  2.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:   9%|▉         | 147/1554 [01:25<07:10,  3.27it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  10%|▉         | 148/1554 [01:26<06:00,  3.90it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  10%|▉         | 149/1554 [01:26<05:13,  4.48it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  12%|█▏        | 180/1554 [01:35<12:56,  1.77it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  12%|█▏        | 181/1554 [01:35<13:28,  1.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  12%|█▏        | 182/1554 [01:36<14:08,  1.62it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  12%|█▏        | 183/1554 [01:37<14:39,  1.56it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  12%|█▏        | 184/1554 [01:38<15:02,  1.52it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  12%|█▏        | 185/1554 [01:38<14:45,  1.55it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  14%|█▍        | 222/1554 [01:48<13:25,  1.65it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  14%|█▍        | 223/1554 [01:49<14:48,  1.50it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  14%|█▍        | 224/1554 [01:50<16:03,  1.38it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  14%|█▍        | 225/1554 [01:51<16:39,  1.33it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  15%|█▍        | 226/1554 [01:51<17:02,  1.30it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  15%|█▍        | 227/1554 [01:52<17:26,  1.27it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  17%|█▋        | 264/1554 [02:02<12:21,  1.74it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  17%|█▋        | 265/1554 [02:03<12:26,  1.73it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  17%|█▋        | 266/1554 [02:03<12:37,  1.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  17%|█▋        | 267/1554 [02:04<12:29,  1.72it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  17%|█▋        | 268/1554 [02:04<12:28,  1.72it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  17%|█▋        | 269/1554 [02:05<12:37,  1.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▎       | 366/1554 [02:53<16:24,  1.21it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▎       | 367/1554 [02:54<15:49,  1.25it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▎       | 368/1554 [02:55<15:37,  1.27it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▎       | 369/1554 [02:56<15:12,  1.30it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 370/1554 [02:56<15:02,  1.31it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 371/1554 [02:57<15:09,  1.30it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 372/1554 [02:58<14:52,  1.32it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 373/1554 [02:59<15:16,  1.29it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 374/1554 [03:00<16:21,  1.20it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 375/1554 [03:01<16:23,  1.20it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 376/1554 [03:01<16:16,  1.21it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  24%|██▍       | 377/1554 [03:02<15:17,  1.28it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  25%|██▌       | 396/1554 [03:15<15:47,  1.22it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  26%|██▌       | 397/1554 [03:15<12:25,  1.55it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  26%|██▌       | 398/1554 [03:15<09:51,  1.96it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  26%|██▌       | 399/1554 [03:16<08:01,  2.40it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  26%|██▌       | 400/1554 [03:16<06:51,  2.81it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  26%|██▌       | 401/1554 [03:16<05:44,  3.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  28%|██▊       | 432/1554 [03:26<12:15,  1.53it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  28%|██▊       | 433/1554 [03:26<12:37,  1.48it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  28%|██▊       | 434/1554 [03:27<12:44,  1.46it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  28%|██▊       | 435/1554 [03:28<12:39,  1.47it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  28%|██▊       | 436/1554 [03:28<12:48,  1.45it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  28%|██▊       | 437/1554 [03:29<13:16,  1.40it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  31%|███       | 474/1554 [03:39<10:18,  1.75it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  31%|███       | 475/1554 [03:40<11:48,  1.52it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  31%|███       | 476/1554 [03:41<12:47,  1.40it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  31%|███       | 477/1554 [03:41<13:16,  1.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  31%|███       | 478/1554 [03:42<14:03,  1.28it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  31%|███       | 479/1554 [03:43<14:16,  1.25it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  33%|███▎      | 516/1554 [03:54<10:08,  1.71it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  33%|███▎      | 517/1554 [03:54<10:08,  1.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  33%|███▎      | 518/1554 [03:55<10:11,  1.69it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  33%|███▎      | 519/1554 [03:55<10:02,  1.72it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  33%|███▎      | 520/1554 [03:56<10:05,  1.71it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  34%|███▎      | 521/1554 [03:57<10:27,  1.65it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|███▉      | 618/1554 [04:42<10:42,  1.46it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|███▉      | 619/1554 [04:42<10:36,  1.47it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|███▉      | 620/1554 [04:43<10:31,  1.48it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|███▉      | 621/1554 [04:44<10:32,  1.47it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 622/1554 [04:44<10:40,  1.45it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 623/1554 [04:45<10:43,  1.45it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 624/1554 [04:46<10:41,  1.45it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 625/1554 [04:46<10:56,  1.41it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 626/1554 [04:47<11:18,  1.37it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 627/1554 [04:48<11:46,  1.31it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 628/1554 [04:49<11:53,  1.30it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  40%|████      | 629/1554 [04:49<11:24,  1.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  42%|████▏     | 648/1554 [05:02<10:48,  1.40it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  42%|████▏     | 649/1554 [05:02<08:18,  1.81it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  42%|████▏     | 650/1554 [05:03<06:34,  2.29it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  42%|████▏     | 651/1554 [05:03<05:18,  2.84it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  42%|████▏     | 652/1554 [05:03<04:29,  3.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  42%|████▏     | 653/1554 [05:03<03:55,  3.82it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  44%|████▍     | 684/1554 [05:12<08:36,  1.68it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  44%|████▍     | 685/1554 [05:13<09:07,  1.59it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  44%|████▍     | 686/1554 [05:13<09:19,  1.55it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  44%|████▍     | 687/1554 [05:14<09:27,  1.53it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  44%|████▍     | 688/1554 [05:15<10:10,  1.42it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  44%|████▍     | 689/1554 [05:16<10:32,  1.37it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  47%|████▋     | 726/1554 [05:26<08:10,  1.69it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  47%|████▋     | 727/1554 [05:27<09:11,  1.50it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  47%|████▋     | 728/1554 [05:28<10:06,  1.36it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  47%|████▋     | 729/1554 [05:29<10:54,  1.26it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  47%|████▋     | 730/1554 [05:30<11:15,  1.22it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  47%|████▋     | 731/1554 [05:31<11:58,  1.15it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  49%|████▉     | 768/1554 [05:41<07:40,  1.71it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  49%|████▉     | 769/1554 [05:42<07:50,  1.67it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  50%|████▉     | 770/1554 [05:42<08:22,  1.56it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  50%|████▉     | 771/1554 [05:43<08:33,  1.52it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  50%|████▉     | 772/1554 [05:44<08:23,  1.55it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  50%|████▉     | 773/1554 [05:44<08:27,  1.54it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▌    | 870/1554 [06:31<08:03,  1.41it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▌    | 871/1554 [06:31<07:56,  1.43it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▌    | 872/1554 [06:32<07:58,  1.43it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▌    | 873/1554 [06:33<07:56,  1.43it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▌    | 874/1554 [06:33<08:01,  1.41it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▋    | 875/1554 [06:34<07:59,  1.41it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▋    | 876/1554 [06:35<07:49,  1.44it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▋    | 877/1554 [06:36<07:59,  1.41it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  56%|█████▋    | 878/1554 [06:36<08:06,  1.39it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  57%|█████▋    | 879/1554 [06:37<08:11,  1.37it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  57%|█████▋    | 880/1554 [06:38<08:16,  1.36it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  57%|█████▋    | 881/1554 [06:38<07:58,  1.41it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  58%|█████▊    | 900/1554 [06:50<07:13,  1.51it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  58%|█████▊    | 901/1554 [06:50<05:31,  1.97it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  58%|█████▊    | 902/1554 [06:50<04:22,  2.48it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  58%|█████▊    | 903/1554 [06:50<03:41,  2.94it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  58%|█████▊    | 904/1554 [06:50<03:11,  3.40it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  58%|█████▊    | 905/1554 [06:51<02:46,  3.91it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  60%|██████    | 936/1554 [06:59<06:02,  1.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  60%|██████    | 937/1554 [07:00<06:23,  1.61it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  60%|██████    | 938/1554 [07:01<06:27,  1.59it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  60%|██████    | 939/1554 [07:01<06:31,  1.57it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  60%|██████    | 940/1554 [07:02<06:34,  1.56it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  61%|██████    | 941/1554 [07:03<06:33,  1.56it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  63%|██████▎   | 978/1554 [07:13<05:51,  1.64it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  63%|██████▎   | 979/1554 [07:14<06:31,  1.47it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  63%|██████▎   | 980/1554 [07:14<07:01,  1.36it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  63%|██████▎   | 981/1554 [07:15<07:20,  1.30it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  63%|██████▎   | 982/1554 [07:16<07:37,  1.25it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  63%|██████▎   | 983/1554 [07:17<08:19,  1.14it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  66%|██████▌   | 1020/1554 [07:28<05:31,  1.61it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  66%|██████▌   | 1021/1554 [07:29<05:27,  1.63it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  66%|██████▌   | 1022/1554 [07:29<05:22,  1.65it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  66%|██████▌   | 1023/1554 [07:30<05:27,  1.62it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# ...
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  79%|███████▉  | 1231/1554 [08:56<03:26,  1.56it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  79%|███████▉  | 1232/1554 [08:57<03:42,  1.45it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  79%|███████▉  | 1233/1554 [08:58<03:58,  1.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  79%|███████▉  | 1234/1554 [08:59<04:04,  1.31it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  79%|███████▉  | 1235/1554 [09:00<04:07,  1.29it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  82%|████████▏ | 1272/1554 [09:10<02:41,  1.75it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  82%|████████▏ | 1273/1554 [09:10<02:40,  1.75it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  82%|████████▏ | 1274/1554 [09:11<02:38,  1.77it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  82%|████████▏ | 1275/1554 [09:11<02:37,  1.77it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  82%|████████▏ | 1276/1554 [09:12<02:37,  1.77it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  82%|████████▏ | 1277/1554 [09:12<02:36,  1.77it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  86%|████████▌ | 1332/1554 [09:31<02:13,  1.67it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  86%|████████▌ | 1333/1554 [09:32<02:09,  1.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  86%|████████▌ | 1338/1554 [09:35<02:07,  1.69it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  86%|████████▌ | 1339/1554 [09:35<02:04,  1.72it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  86%|████████▌ | 1340/1554 [09:36<02:08,  1.67it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  88%|████████▊ | 1374/1554 [09:58<02:11,  1.37it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  88%|████████▊ | 1375/1554 [09:59<02:10,  1.37it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▊ | 1376/1554 [10:00<02:10,  1.37it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▊ | 1377/1554 [10:01<02:14,  1.32it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▊ | 1378/1554 [10:01<02:12,  1.32it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▊ | 1379/1554 [10:02<02:13,  1.31it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▉ | 1380/1554 [10:03<02:08,  1.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▉ | 1381/1554 [10:04<02:08,  1.34it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▉ | 1382/1554 [10:04<02:08,  1.34it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▉ | 1383/1554 [10:05<02:06,  1.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▉ | 1384/1554 [10:06<02:03,  1.38it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  89%|████████▉ | 1385/1554 [10:06<01:58,  1.43it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  93%|█████████▎| 1440/1554 [10:27<01:04,  1.76it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  93%|█████████▎| 1441/1554 [10:27<01:07,  1.67it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  93%|█████████▎| 1442/1554 [10:28<01:09,  1.62it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  93%|█████████▎| 1443/1554 [10:29<01:11,  1.54it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  93%|█████████▎| 1444/1554 [10:29<01:11,  1.54it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  93%|█████████▎| 1445/1554 [10:30<01:11,  1.53it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  95%|█████████▌| 1482/1554 [10:40<00:41,  1.75it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  95%|█████████▌| 1483/1554 [10:41<00:45,  1.56it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  95%|█████████▌| 1484/1554 [10:41<00:49,  1.41it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  96%|█████████▌| 1485/1554 [10:42<00:50,  1.37it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  96%|█████████▌| 1486/1554 [10:43<00:50,  1.35it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  96%|█████████▌| 1487/1554 [10:44<00:50,  1.32it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  98%|█████████▊| 1524/1554 [10:54<00:17,  1.69it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  98%|█████████▊| 1525/1554 [10:54<00:17,  1.69it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  98%|█████████▊| 1526/1554 [10:55<00:16,  1.69it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  98%|█████████▊| 1527/1554 [10:56<00:16,  1.65it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  98%|█████████▊| 1528/1554 [10:56<00:15,  1.67it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...:  98%|█████████▊| 1529/1554 [10:57<00:14,  1.70it/s]c:\Users\andre\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# doing parameters search...: 100%|██████████| 1554/1554 [11:00<00:00,  2.35it/s]
# Found best combination! ('linear', 1) w. accuracy of 0.9167919799498746.

# %%
best_comb = tuple(["linear", 1, 1, 3, 0])

n_princ_cs = [1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 54]
res_per_pc = np.zeros(len(n_princ_cs))

X_train_interp, X_test_interp = base.interpolate_data(X_train, n_coords), base.interpolate_data(X_test, n_coords)
X_train_interp = base.concatenate_examples(X_train_interp)
X_test_interp = base.concatenate_examples(X_test_interp)
SC = StandardScaler()
SC.fit(X_train_interp)
X_train_interp = SC.transform(X_train_interp)
X_test_interp = SC.transform(X_test_interp)

kpca = KernelPCA(n_components=None, kernel='linear')

principal_comps_train = kpca.fit_transform(X_train_interp)
principal_comps_test = kpca.transform(X_test_interp)
if len(best_comb) == 2:
    best_comb = tuple([best_comb[0], best_comb[1], 1, 3, 0])
elif len(best_comb) == 3:
    best_comb = tuple([best_comb[0], best_comb[1], best_comb[2], 3, 0])
svc = SVC(kernel=best_comb[0], C=best_comb[1], gamma=best_comb[2], degree=best_comb[3], coef0=best_comb[4])
for i, n_pc in enumerate(n_princ_cs):
    princ_components = principal_comps_train[:, :n_pc]
    svc.fit(princ_components, y_train.values)
    test_princ_components = principal_comps_test[:, :n_pc]
    predictions = svc.predict(test_princ_components)
    res = accuracy_score(y_test.values, predictions)
    res_per_pc[i] = res
print(f'Reached an accuracy of {res_per_pc[-1]}.')
svc_res_per_pc = res_per_pc
# Out:
# Reached an accuracy of 0.9350877192982456.

# %% [markdown]
# ## Random Forests classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ParameterGrid
import itertools
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from utils import *
from tqdm import tqdm
criterion = ['gini', 'entropy']
n_estimators = [10, 25, 50, 100, 200]
max_depth = [10, 20, 30, 50, 100]
min_samples_split = [2, 6, 10] # minimum sample number to split a node
min_samples_leaf = [1, 3, 4] # minimum sample number that can be stored in a leaf node
params_grid = {'criterion':criterion,
'n_estimators': n_estimators,
'max_depth': max_depth,
'min_samples_split': min_samples_split,
'min_samples_leaf': min_samples_leaf,
}

n_pcs = 54
n_coords = 60
params_list = list(ParameterGrid(params_grid))
acc_scores = np.zeros(len(params_list))
for train_index, val_index in skf.split(X_train, y_train):
    X_train_cv = X_train.iloc[train_index]
    y_train_cv = y_train.iloc[train_index]
    X_val_cv = X_train.iloc[val_index]
    y_val_cv = y_train.iloc[val_index]
    X_train_interp, X_test_interp = base.interpolate_data(X_train_cv, n_coords), base.interpolate_data(X_val_cv, n_coords)
    X_train_interp = base.concatenate_examples(X_train_interp)
    X_test_interp = base.concatenate_examples(X_test_interp)
    SC = StandardScaler()
    SC.fit(X_train_interp)
    X_train_interp = SC.transform(X_train_interp)
    X_test_interp = SC.transform(X_test_interp)
    kpca = KernelPCA(n_components=None, kernel='linear')
    principal_comps_train = kpca.fit_transform(X_train_interp)
    principal_comps_test = kpca.transform(X_test_interp)
    princ_components = principal_comps_train[:, :n_pcs]
    test_princ_components = principal_comps_test[:, :n_pcs]
    for i, params in enumerate(tqdm(params_list)):
        rf = RandomForestClassifier(criterion = params['criterion'], n_estimators=params['n_estimators'], max_depth=params['max_depth'], min_samples_split=params['min_samples_split'], min_samples_leaf=params['min_samples_leaf'])
        rf.fit(princ_components, y_train_cv.values)
        predictions = rf.predict(test_princ_components)
        res = accuracy_score(y_val_cv.values, predictions)
        acc_scores[i] += res
acc_scores = acc_scores / n_folds
best_idx = np.argmax(acc_scores)
# Out:
# 100%|██████████| 450/450 [30:30<00:00,  4.07s/it]
# 100%|██████████| 450/450 [30:55<00:00,  4.12s/it]
# 100%|██████████| 450/450 [30:54<00:00,  4.12s/it]
# 100%|██████████| 450/450 [30:41<00:00,  4.09s/it]
# 100%|██████████| 450/450 [30:17<00:00,  4.04s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-36b00086d1aa> in <module>
#      49 acc_scores = acc_scores / n_folds
#      50 best_idx = np.argmax(acc_scores)
# ---> 51 print(f'Found best combination! {params_comb[best_idx]} w. accuracy of {acc_scores[best_idx]}.')
#      52 best_comb = params_comb[best_idx]
#      53
#
# NameError: name 'params_comb' is not defined

# %%
print(f'Found best combination! {params_list[best_idx]} w. accuracy of {acc_scores[best_idx]}.')
best_comb = params_list[best_idx]
# Out:
# Found best combination! {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} w. accuracy of 0.8902255639097744.

# %%
n_princ_cs = [1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
res_per_pc = np.zeros(len(n_princ_cs))

X_train_interp, X_test_interp = base.interpolate_data(X_train, n_coords), base.interpolate_data(X_test, n_coords)
X_train_interp = base.concatenate_examples(X_train_interp)
X_test_interp = base.concatenate_examples(X_test_interp)
SC = StandardScaler()
SC.fit(X_train_interp)
X_train_interp = SC.transform(X_train_interp)
X_test_interp = SC.transform(X_test_interp)
kpca = KernelPCA(n_components=None, kernel='linear')
principal_comps_train = kpca.fit_transform(X_train_interp)
principal_comps_test = kpca.transform(X_test_interp)
rf = RandomForestClassifier(criterion = best_comb['criterion'], n_estimators=best_comb['n_estimators'], max_depth=best_comb['max_depth'], min_samples_split=best_comb['min_samples_split'], min_samples_leaf=best_comb['min_samples_leaf'])
for i, n_pc in enumerate(n_princ_cs):
    princ_components = principal_comps_train[:, :n_pc]
    rf.fit(princ_components, y_train.values)
    test_princ_components = principal_comps_test[:, :n_pc]
    predictions = rf.predict(test_princ_components)
    res = accuracy_score(y_test.values, predictions)
    res_per_pc[i] += res

print(f'Reached an accuracy of {res_per_pc[-1]}.')
rf_res_per_pc = res_per_pc
# Out:
# Reached an accuracy of 0.8894736842105263.

# %%
print('SVC accuracy x n principal components: ', svc_res_per_pc)
print('RF accuracy x n principal components: ', rf_res_per_pc)
# Out:
# SVC accuracy x n principal components:  [0.00526316 0.26491228 0.44912281 0.65263158 0.79649123 0.84035088
#  0.88421053 0.89649123 0.91052632 0.91754386 0.93508772 0.93508772]
# RF accuracy x n principal components:  [0.01754386 0.22280702 0.3245614  0.49122807 0.59298246 0.66842105
#  0.79298246 0.81754386 0.85614035 0.85614035 0.86491228 0.88947368]
